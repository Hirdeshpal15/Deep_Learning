# %% [markdown]
# ## Precision

# %% [markdown]
# ![Precision.png](attachment:34a5472e-3840-4146-83c8-315155c12c28.png)

# %% [markdown]
# ## Recall

# %% [markdown]
# ![Recall.png](attachment:6bc78da9-aad8-4b89-aba7-aa3df6d68746.png)

# %% [markdown]
# ## Precision Vs Recall

# %% [markdown]
# ![Precision vs Recall.png](attachment:f638a943-c42d-4c0a-a935-79104d35741e.png)
